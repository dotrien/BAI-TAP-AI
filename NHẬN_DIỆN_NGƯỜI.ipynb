# %%
# Khai báo và sử dụng các thư viện sau
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import SGD, RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import validation 
from sklearn import preprocessing
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Chuyển đến file Google Drive chứa bộ ảnh đã tạo
# %cd"/content/drive/MyDrive/Colab Notebooks/BTVN/Nhan_dien_nguoi/"
# Out:
# /content/drive/MyDrive/Colab Notebooks/BTVN/Nhan_dien_nguoi

# %%
# Tạo ra class ImageDataGenerator để chỉnh sửa ảnh 
train_datagen=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
# Tạo bộ dữ liệu training set
training_set=train_datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/BTVN/Nhan_dien_nguoi/Training_set',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 120 images belonging to 3 classes.

# %%
# Tạo bộ dữ liệu validation
validation=train_datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/BTVN/Nhan_dien_nguoi/Validation',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 18 images belonging to 3 classes.

# %%
# Các nhãn có trong bộ dữ liệu training set
training_set.class_indices
# Out:
# {'DUOC': 0, 'GIANG': 1, 'TRIEN': 2}

# %%
# Các nhãn có trong bộ dữ liệu validation
validation.class_indices
# Out:
# {'DUOC': 0, 'GIANG': 1, 'TRIEN': 2}

# %%
# Tạo ra mạng CNN để train mô hình
model=Sequential()
# Tích chập 32 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) 
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))
# Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) 
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))
# Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) 
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))
# Duỗi thẳng dữ liệu 
model.add(Flatten())
# Tạo lớp ẩn thứ nhất với 128 tín hiệu ra
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
# Tạo lớp ẩn thứ hai với 3 tín hiệu ra
model.add(Dense(3,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 128)               5308544
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 5,595,939
# Trainable params: 5,595,939
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Biên dịch 
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
# Gán biến lại để vẽ đồ thị, với 500 lần học (epochs), mỗi lần học thì chỉ học␣128 dữ liệu (batch_size), khi sai số không thay đổi trong 20 lần học thì sẽ␣ dừng học 
history=model.fit(training_set,epochs=100,batch_size=128,verbose=1, validation_data=validation, callbacks=[EarlyStopping(monitor='val_loss', patience=20)])
# Out:
# Epoch 1/100
# 4/4 [==============================] - 18s 4s/step - loss: 5.4612 - accuracy: 0.3917 - val_loss: 0.9929 - val_accuracy: 0.3333
# Epoch 2/100
# 4/4 [==============================] - 17s 4s/step - loss: 1.1211 - accuracy: 0.3333 - val_loss: 0.9466 - val_accuracy: 0.4444
# Epoch 3/100
# 4/4 [==============================] - 16s 4s/step - loss: 0.7906 - accuracy: 0.7583 - val_loss: 0.6113 - val_accuracy: 0.7778
# Epoch 4/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.4433 - accuracy: 0.8417 - val_loss: 0.4615 - val_accuracy: 0.8889
# Epoch 5/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.2160 - accuracy: 0.9500 - val_loss: 0.4594 - val_accuracy: 0.9444
# Epoch 6/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.1045 - accuracy: 0.9917 - val_loss: 0.7734 - val_accuracy: 0.8889
# Epoch 7/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0885 - accuracy: 0.9750 - val_loss: 0.4294 - val_accuracy: 0.8889
# Epoch 8/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.4321 - val_accuracy: 0.9444
# Epoch 9/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0221 - accuracy: 0.9833 - val_loss: 0.6907 - val_accuracy: 0.8333
# Epoch 10/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0224 - accuracy: 0.9917 - val_loss: 0.8146 - val_accuracy: 0.9444
# Epoch 11/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0250 - accuracy: 0.9917 - val_loss: 0.7244 - val_accuracy: 0.9444
# Epoch 12/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0292 - accuracy: 0.9833 - val_loss: 0.6538 - val_accuracy: 0.9444
# Epoch 13/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0163 - accuracy: 0.9917 - val_loss: 0.4565 - val_accuracy: 0.9444
# Epoch 14/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.6072 - val_accuracy: 0.9444
# Epoch 15/100
# 4/4 [==============================] - 16s 4s/step - loss: 5.4410e-04 - accuracy: 1.0000 - val_loss: 0.4293 - val_accuracy: 0.9444
# Epoch 16/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0120 - accuracy: 0.9917 - val_loss: 0.3316 - val_accuracy: 0.9444
# Epoch 17/100
# 4/4 [==============================] - 17s 4s/step - loss: 2.3184e-04 - accuracy: 1.0000 - val_loss: 0.6544 - val_accuracy: 0.8889
# Epoch 18/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0337 - accuracy: 0.9833 - val_loss: 0.5816 - val_accuracy: 0.9444
# Epoch 19/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0457 - accuracy: 0.9833 - val_loss: 0.3609 - val_accuracy: 0.8889
# Epoch 20/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0214 - accuracy: 0.9833 - val_loss: 0.2999 - val_accuracy: 0.8889
# Epoch 21/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0250 - accuracy: 0.9917 - val_loss: 0.7017 - val_accuracy: 0.9444
# Epoch 22/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0173 - accuracy: 0.9917 - val_loss: 0.3277 - val_accuracy: 0.9444
# Epoch 23/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.3247 - val_accuracy: 0.8889
# Epoch 24/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.3127 - val_accuracy: 0.9444
# Epoch 25/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0183 - accuracy: 0.9917 - val_loss: 0.1211 - val_accuracy: 0.8889
# Epoch 26/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.3607 - val_accuracy: 0.8889
# Epoch 27/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0209 - accuracy: 0.9917 - val_loss: 0.6727 - val_accuracy: 0.9444
# Epoch 28/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0110 - accuracy: 0.9917 - val_loss: 0.3146 - val_accuracy: 0.9444
# Epoch 29/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.5531 - val_accuracy: 0.9444
# Epoch 30/100
# 4/4 [==============================] - 17s 4s/step - loss: 3.2648e-04 - accuracy: 1.0000 - val_loss: 0.7361 - val_accuracy: 0.9444
# Epoch 31/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.6207 - val_accuracy: 0.8889
# Epoch 32/100
# 4/4 [==============================] - 17s 4s/step - loss: 7.4634e-04 - accuracy: 1.0000 - val_loss: 1.8243 - val_accuracy: 0.8889
# Epoch 33/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.5339 - val_accuracy: 0.9444
# Epoch 34/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0729 - accuracy: 0.9917 - val_loss: 0.2844 - val_accuracy: 0.9444
# Epoch 35/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.8114 - val_accuracy: 0.9444
# Epoch 36/100
# 4/4 [==============================] - 16s 4s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3748 - val_accuracy: 0.9444
# Epoch 37/100
# 4/4 [==============================] - 16s 4s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.4468 - val_accuracy: 0.9444
# Epoch 38/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.7654 - val_accuracy: 0.9444
# Epoch 39/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.4712 - val_accuracy: 0.9444
# Epoch 40/100
# 4/4 [==============================] - 16s 4s/step - loss: 0.0073 - accuracy: 0.9917 - val_loss: 1.2220 - val_accuracy: 0.9444
# Epoch 41/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.8246 - val_accuracy: 0.9444
# Epoch 42/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.9578 - val_accuracy: 0.9444
# Epoch 43/100
# 4/4 [==============================] - 17s 4s/step - loss: 0.0079 - accuracy: 0.9917 - val_loss: 1.1037 - val_accuracy: 0.9444
# Epoch 44/100
# 4/4 [==============================] - 17s 4s/step - loss: 1.8249e-04 - accuracy: 1.0000 - val_loss: 1.8784 - val_accuracy: 0.9444
# Epoch 45/100
# 4/4 [==============================] - 17s 4s/step - loss: 3.1294e-05 - accuracy: 1.0000 - val_loss: 0.7637 - val_accuracy: 0.9444

# %%
# Đánh giá độ chính xác của mô hình 
Score=model.evaluate(training_set,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# Train Loss 0.0006390956696122885
# Train Accuracy 1.0

# %%
# Vẽ đồ thị giữa số lần học (Epochs) và độ chính xác (Accuracy)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# Lưu lại
model.save("Nhan_dien_nguoi.h5")

# %%
# Tải mô hình 
model_CNN=load_model('Nhan_dien_nguoi.h5')

# %%
# Kiểm tra hình của từng bạn với bộ dữ liệu test_set

# %%
img=load_img("/content/drive/MyDrive/Colab Notebooks/BTVN/Nhan_dien_nguoi/Test_set/DuocT1.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='DUOC'
if round(result[0][1])==1:
  prediction='GIANG'
if round(result[0][2])==1:
  prediction='TRIEN'
print(prediction)
# Out:
# DUOC

# %%
img=load_img("/content/drive/MyDrive/Colab Notebooks/BTVN/Nhan_dien_nguoi/Test_set/GiangT1.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='DUOC'
if round(result[0][1])==1:
  prediction='GIANG'
if round(result[0][2])==1:
  prediction='TRIEN'
print(prediction)
# Out:
# GIANG

# %%
img=load_img("/content/drive/MyDrive/Colab Notebooks/BTVN/Nhan_dien_nguoi/Test_set/TrienT3.jpg",target_size=(150,150))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='DUOC'
if round(result[0][1])==1:
  prediction='GIANG'
if round(result[0][2])==1:
  prediction='TRIEN'
print(prediction)
# Out:
# TRIEN

# %%
  # Chuyển sang pdf
from google.colab import drive
drive.mount('/content/drive')
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-generic-recommended
# !wget -nc https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py
from colab_pdf import colab_pdf
colab_pdf('NHẬN DIỆN NGƯỜI.ipynb')
